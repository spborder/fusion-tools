# %% [markdown]
# # Testing out Jupyter Notebook additional app_options

# %%
import os
import sys
import threading
print(os.getcwd())
sys.path.append('../src/')

from fusion_tools import Visualization, DSAHandler
from fusion_tools.tileserver import DSATileServer
from fusion_tools.components import SlideMap,OverlayOptions, PropertyViewer, PropertyPlotter, HRAViewer
from fusion_tools.utils.shapes import align_object_props

import pandas as pd
# Out:
# c:\Users\samuelborder\Desktop\HIVE_Stuff\FUSION\Tools\fusion-tools\tests
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 7
#       4 print(os.getcwd())
#       5 sys.path.append('./fusion_tools/src/')
# ----> 7 from fusion_tools import Visualization, DSAHandler
#       8 from fusion_tools.tileserver import DSATileServer
#       9 from fusion_tools.components import SlideMap,OverlayOptions, PropertyViewer, PropertyPlotter, HRAViewer
#
# ModuleNotFoundError: No module named 'fusion_tools'

# %%
# Grabbing first item from demo DSA instance
base_url = 'http://ec2-3-230-122-132.compute-1.amazonaws.com:8080/api/v1'
item_id = '64f545302d82d04be3e39eec'

# Starting visualization session
tile_server = DSATileServer(
    api_url = base_url,
    item_id = item_id
)

# Starting the DSAHandler to grab information:
dsa_handler = DSAHandler(
    girderApiUrl = base_url
)

annotations = dsa_handler.get_annotations(
    item = item_id
)

vis_session = Visualization(
    components = [
        [
            SlideMap(
                tile_server = tile_server,
                annotations = annotations
            ),
            [
                OverlayOptions(
                    geojson_anns=annotations
                ),
                PropertyViewer(
                    geojson_list=annotations
                ),
                PropertyPlotter(
                    geojson_list=annotations
                ),
                HRAViewer()
            ]
        ]
    ],
    app_options = {'jupyter_mode': 'inline'}
)

vis_session.start()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 28
#      12 dsa_handler = DSAHandler(
#      13     girderApiUrl = base_url
#      14 )
#      16 annotations = dsa_handler.get_annotations(
#      17     item = item_id
#      18 )
#      20 vis_session = Visualization(
#      21     components = [
#      22         [
#      23             SlideMap(
#      24                 tile_server = tile_server,
#      25                 annotations = annotations
#      26             ),
#      27             [
# ---> 28                 OverlayOptions(
#      29                     geojson_anns=annotations
#      30                 ),
#      31                 PropertyViewer(
#      32                     geojson_list=annotations
#      33                 ),
#      34                 PropertyPlotter(
#      35                     geojson_list=annotations
#      36                 ),
#      37                 HRAViewer()
#      38             ]
#      39         ]
#      40     ],
#      41     app_options = {'jupyter_mode': 'inline'}
#      42 )
#      44 vis_session.start()
#
# File c:\Users\samuelborder\AppData\Local\Programs\Python\Python311\Lib\site-packages\fusion_tools\components\tools.py:80, in OverlayOptions.__init__(self, geojson_anns, reference_object, ignore_list, property_depth)
#      78 self.title = 'Overlay Options'
#      79 self.blueprint = DashBlueprint()
# ---> 80 self.blueprint.layout = self.gen_layout()
#      81 self.js_namespace = Namespace("fusionTools","default")
#      83 # Add callbacks here
#
# File c:\Users\samuelborder\AppData\Local\Programs\Python\Python311\Lib\site-packages\fusion_tools\components\tools.py:250, in OverlayOptions.gen_layout(self)
#      87 """Generating OverlayOptions layout, added to DashBlueprint() object to be embedded in larger layout.
#      88
#      89 :return: OverlayOptions layout
#      90 :rtype: dash.html.Div.Div
#      91 """
#      93 adv_colormaps = [
#      94     'Custom Palettes',
#      95     'blue->red',
#    (...)
#     111     'Pastel2', 'Pastel1',
#     112 ]
#     115 layout = html.Div([
#     116     dbc.Card(
#     117         dbc.CardBody([
#     118             dbc.Row(
#     119                 html.H3('Overlay Options')
#     120             ),
#     121             html.Hr(),
#     122             dbc.Row(
#     123                 'Select options below to adjust overlay color, transparency, and line color for structures on your slide.'
#     124             ),
#     125             html.Hr(),
#     126             dbc.Row([
#     127                 dbc.Col(
#     128                     dbc.Label(
#     129                         'Select Overlay Property: ',
#     130                         html_for = {'type': 'overlay-drop','index': 0}
#     131                     ),
#     132                     md = 3
#     133                 ),
#     134                 dbc.Col(
#     135                     dcc.Dropdown(
#     136                         options = [
#     137                             {'label': i, 'value': i}
#     138                             for i in self.overlay_options
#     139                         ],
#     140                         value = [],
#     141                         multi = False,
#     142                         id = {'type': 'overlay-drop','index': 0}
#     143                     ),
#     144                     md = 9
#     145                 )
#     146             ]),
#     147             html.Div(
#     148                 dcc.Store(
#     149                     id = {'type': 'overlay-property-info','index':0},
#     150                     data = json.dumps(self.overlay_info),
#     151                     storage_type='memory'
#     152                 )
#     153             ),
#     154             html.Hr(),
#     155             dbc.Row([
#     156                 dbc.Col(
#     157                     dbc.Label(
#     158                         'Adjust Overlay Transparency: ',
#     159                         html_for = {'type': 'overlay-trans-slider','index': 0}
#     160                     ),
#     161                     md = 3
#     162                 ),
#     163                 dbc.Col(
#     164                     dcc.Slider(
#     165                         min = 0,
#     166                         max = 100,
#     167                         step = 10,
#     168                         value = 50,
#     169                         id = {'type': 'overlay-trans-slider','index': 0}
#     170                     )
#     171                 )
#     172             ]),
#     173             html.Hr(),
#     174             dbc.Row([
#     175                 dbc.Label('Filter Structures: ',html_for = {'type': 'add-filter-parent','index': 0}),
#     176                 html.Div('Click the icon below to add a filter.')
#     177             ]),
#     178             dbc.Row([
#     179                 html.Div(
#     180                     id = {'type': 'add-filter-parent','index': 0},
#     181                     children = []
#     182                 )
#     183             ],align='center'),
#     184             dbc.Row([
#     185                 dbc.Col([
#     186                     html.Div([
#     187                         html.A(
#     188                             html.I(
#     189                                 className = 'bi bi-filter-circle fa-2x',
#     190                                 n_clicks = 0,
#     191                                 id = {'type': 'add-filter-butt','index': 0},
#     192                             )
#     193                         ),
#     194                         dbc.Tooltip(
#     195                             target = {'type': 'add-filter-butt','index': 0},
#     196                             children = 'Click to add a filter'
#     197                         )
#     198                     ])
#     199                 ],md = 2),
#     200                 dbc.Col([
#     201                     html.Div([
#     202                         html.A(
#     203                             html.I(
#     204                                 className = 'fa-solid fa-layer-group fa-2x',
#     205                                 n_clicks = 0,
#     206                                 id = {'type': 'create-layer-from-filter','index': 0},
#     207                             )
#     208                         ),
#     209                         dbc.Tooltip(
#     210                             target = {'type': 'create-layer-from-filter','index': 0},
#     211                             children = 'Create new layer from filters'
#     212                         )
#     213                     ])
#     214                 ],md = 2)
#     215             ],align='center', justify='center'),
#     216             html.Hr(),
#     217             dbc.Row(
#     218                 dbc.Label('Update Structure Boundary Color',html_for = {'type': 'feature-lineColor-opts','index': 0})
#     219             ),
#     220             dbc.Row([
#     221                 dbc.Tabs(
#     222                     id = {'type': 'feature-lineColor-opts','index': 0},
#     223                     children = [
#     224                         dbc.Tab(
#     225                             children = [
#     226                                 dmc.ColorPicker(
#     227                                     id = {'type': 'feature-lineColor','index': f_idx},
#     228                                     format = 'hex',
#     229                                     value = '#FFFFFF',
#     230                                     fullWidth=True
#     231                                 ),
#     232                                 dbc.Button(
#     233                                     id = {'type': 'feature-lineColor-butt','index': f_idx},
#     234                                     children = ['Update Boundary Color'],
#     235                                     className = 'd-grid col-12 mx-auto',
#     236                                     n_clicks = 0
#     237                                 )
#     238                             ],
#     239                             label = f
#     240                         )
#     241                         for f_idx, f in enumerate(self.feature_names)
#     242                     ]
#     243                 )
#     244             ],style = {'marginBottom':'10px'}),
#     245             dbc.Row([
#     246                 dbc.Accordion(
#     247                     id = {'type':'adv-overlay-accordion','index': 0},
#     248                     start_collapsed = True,
#     249                     children = [
# --> 250                         dbc.AccordionItem(
#     251                             title = dcc.Markdown('*Advanced Overlay Options*'),
#     252                             children = [
#     253                                 dbc.Card([
#     254                                     dbc.CardBody([
#     255                                         html.Div([
#     256                                             dbc.InputGroup([
#     257                                                 dbc.Input(
#     258                                                     id = {'type': 'adv-overlay-colorbar-width','index': 0},
#     259                                                     placeholder = 'Colorbar Width',
#     260                                                     type = 'number',
#     261                                                     value = 300,
#     262                                                     min = 0,
#     263                                                     max = 1000,
#     264                                                     step = 50
#     265                                                 ),
#     266                                                 dbc.InputGroupText(
#     267                                                     'pixels'
#     268                                                 )
#     269                                             ]),
#     270                                             dbc.FormText(
#     271                                                 'Width of colorbar'
#     272                                             ),
#     273                                             html.Hr(),
#     274                                             dbc.Select(
#     275                                                 id = {'type': 'adv-overlay-colormap','index': 0},
#     276                                                 placeholder = 'Select colormap options',
#     277                                                 options = [
#     278                                                     {'label': i, 'value': i, 'disabled': ' ' in i}
#     279                                                     for i in adv_colormaps
#     280                                                 ],
#     281                                                 value = 'blue->red'
#     282                                             )
#     283                                         ]),
#     284                                         html.Div(
#     285                                             children = [
#     286                                                 dbc.Button(
#     287                                                     'Update Overlays!',
#     288                                                     className = 'd-grid col-12 mx-auto',
#     289                                                     id = {'type': 'adv-overlay-butt','index': 0},
#     290                                                     n_clicks = 0
#     291                                                 )
#     292                                             ],
#     293                                             style = {'marginTop':'10px'}
#     294                                         )
#     295                                     ])
#     296                                 ])
#     297                             ]
#     298                         ),
#     299                         dbc.AccordionItem(
#     300                             title = dcc.Markdown('*Export Layers*'),
#     301                             children = [
#     302                                 dbc.Card([
#     303                                     dbc.CardBody([
#     304                                         html.Div([
#     305                                             dbc.Button(
#     306                                                 'Export Current Layers',
#     307                                                 id = {'type': 'export-current-layers','index': 0},
#     308                                                 n_clicks = 0,
#     309                                                 className = 'd-grid col-12 mx-auto'
#     310                                             ),
#     311                                             dcc.Download(
#     312                                                 id = {'type': 'export-current-layers-data','index': 0}
#     313                                             )
#     314                                         ])
#     315                                     ])
#     316                                 ])
#     317                             ]
#     318                         )
#     319                     ]
#     320                 )
#     321             ])
#     322         ])
#     323     )
#     324 ],style = {'maxHeight': '100vh','overflow':'scroll'})
#     326 return layout
#
# File c:\Users\samuelborder\AppData\Local\Programs\Python\Python311\Lib\site-packages\dash\development\base_component.py:420, in _explicitize_args.<locals>.wrapper(*args, **kwargs)
#     418 if "self" in kwargs["_explicit_args"]:
#     419     kwargs["_explicit_args"].remove("self")
# --> 420 return func(*args, **kwargs)
#
# File c:\Users\samuelborder\AppData\Local\Programs\Python\Python311\Lib\site-packages\dash_bootstrap_components\_components\AccordionItem.py:69, in AccordionItem.__init__(self, children, id, style, class_name, className, title, item_id, loading_state, **kwargs)
#      66 _locals.update(kwargs)  # For wildcard attrs and excess named props
#      67 args = {k: _locals[k] for k in _explicit_args if k != 'children'}
# ---> 69 super(AccordionItem, self).__init__(children=children, **args)
#
# File c:\Users\samuelborder\AppData\Local\Programs\Python\Python311\Lib\site-packages\dash\development\base_component.py:144, in Component.__init__(self, **kwargs)
#     138     raise TypeError(
#     139         f"{error_string_prefix} received an unexpected keyword argument: `{k}`"
#     140         f"\nAllowed arguments: {allowed_args}"
#     141     )
#     143 if k not in self._base_nodes and isinstance(v, Component):
# --> 144     raise TypeError(
#     145         error_string_prefix
#     146         + " detected a Component for a prop other than `children`\n"
#     147         + f"Prop {k} has value {v!r}\n\n"
#     148         + "Did you forget to wrap multiple `children` in an array?\n"
#     149         + 'For example, it must be html.Div(["a", "b", "c"]) not html.Div("a", "b", "c")\n'
#     150     )
#     152 if k == "id":
#     153     if isinstance(v, dict):
#
# TypeError: The `dash_bootstrap_components.AccordionItem` component (version 1.4.2) detected a Component for a prop other than `children`
# Prop title has value Markdown('*Advanced Overlay Options*')
#
# Did you forget to wrap multiple `children` in an array?
# For example, it must be html.Div(["a", "b", "c"]) not html.Div("a", "b", "c")
